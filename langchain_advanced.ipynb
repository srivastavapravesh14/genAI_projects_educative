# %%
from google.colab import userdata
import os
os.environ["GROQ_API_KEY"] = userdata.get('groq_api_key')

# %%
# !pip install langchain-groq langchain

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

@tool
def calculate_discount(price: float, discount_percentage: float) -> float:
  """
  Calculates the final price after applying a discount.

  Args:
      price (float): The original price of the item.
      discount_percentage (float): The discount percentage (e.g., 20 for 20%).

  Returns:
      float: The final price after the discount is applied.
  """
  if not 0.0 <= discount_percentage <= 100.0:
    raise ValueError("Discount percentage must be between 0 and 100.")
  discount = price * (discount_percentage / 100)
  return price - discount


llm_with_tool = llm.bind_tools([calculate_discount])
result = llm_with_tool.invoke("What is the price of an item that costs rupee 100 after a 10.75% discount?")

print(result.tool_calls)
args = result.tool_calls[0]["args"]
print(calculate_discount.invoke(args))
# Out:
# [{'name': 'calculate_discount', 'args': {'discount_percentage': 10.75, 'price': 100}, 'id': 'fgk1a1c5n', 'type': 'tool_call'}]
# 89.25
